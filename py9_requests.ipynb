# %%
from requests import get

response = get("https://static-maps.yandex.ru/1.x/?"
               "ll=37.677751,55.757718&"
               "spn=0.016457,0.00619&"
               "l=map")
print(response)
# Out:
# <Response [200]>

# %%
with open("map.png", "wb") as file:
    file.write(response.content)

# %%
params = {
    "ll": "37.677751,55.757718",
    "spn": "0.016457,0.00619",
    "l": "map"
}
response = get("<https://static-maps.yandex.ru/1.x/>", params=params)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# /tmp/ipykernel_130194/971809066.py in <cell line: 0>()
#       4     "l": "map"
#       5 }
# ----> 6 response = get("<https://static-maps.yandex.ru/1.x/>", params=params)
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         # Get the appropriate adapter to use
# --> 697         adapter = self.get_adapter(url=request.url)
#     698
#     699         # Start time (approximately) of the request
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in get_adapter(self, url)
#     790
#     791         # Nothing matches :-/
# --> 792         raise InvalidSchema(f"No connection adapters were found for {url!r}")
#     793
#     794     def close(self):
#
# InvalidSchema: No connection adapters were found for '<https://static-maps.yandex.ru/1.x/>'

# %%
from requests import get, ConnectionError

params = {
    "ll": "37.677751,55.757718",
    "spn": "0.016457,0.00619",
    "l": "map"
}

try:
    response = get("<https://static-maps.yandex.ru/1.x/>", params=params)
except ConnectionError:
    print("Проверьте подключение к Сети.")
else:
    with open("map.png", "wb") as file:
        file.write(response.content)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# /tmp/ipykernel_130194/1693285500.py in <cell line: 0>()
#       8
#       9 try:
# ---> 10     response = get("<https://static-maps.yandex.ru/1.x/>", params=params)
#      11 except ConnectionError:
#      12     print("Проверьте подключение к Сети.")
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         # Get the appropriate adapter to use
# --> 697         adapter = self.get_adapter(url=request.url)
#     698
#     699         # Start time (approximately) of the request
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in get_adapter(self, url)
#     790
#     791         # Nothing matches :-/
# --> 792         raise InvalidSchema(f"No connection adapters were found for {url!r}")
#     793
#     794     def close(self):
#
# InvalidSchema: No connection adapters were found for '<https://static-maps.yandex.ru/1.x/>'

# %%
from requests_oauthlib import OAuth2Session
from requests import get, post, put, delete

client_id = ""
client_secret = ""
auth_url = "<https://oauth.yandex.ru/authorize>"
token_url = "<https://oauth.yandex.ru/token>"

oauth = OAuth2Session(client_id=client_id)
authorization_url, state = oauth.authorization_url(auth_url, force_confirm="true")
print("Перейдите по ссылке и авторизуйтесь:", authorization_url)

code = input("Введите одноразовый код: ")

token = oauth.fetch_token(
    token_url=token_url,
    code=code,
    client_secret=client_secret
)

access_token = token["access_token"]
print(access_token)
# Out:
# ---------------------------------------------------------------------------
# InsecureTransportError                    Traceback (most recent call last)
# /tmp/ipykernel_130194/4041507027.py in <cell line: 0>()
#       8
#       9 oauth = OAuth2Session(client_id=client_id)
# ---> 10 authorization_url, state = oauth.authorization_url(auth_url, force_confirm="true")
#      11 print("Перейдите по ссылке и авторизуйтесь:", authorization_url)
#      12
#
# /usr/local/lib/python3.12/dist-packages/requests_oauthlib/oauth2_session.py in authorization_url(self, url, state, **kwargs)
#     190             )
#     191         return (
# --> 192             self._client.prepare_request_uri(
#     193                 url,
#     194                 redirect_uri=self.redirect_uri,
#
# /usr/local/lib/python3.12/dist-packages/oauthlib/oauth2/rfc6749/clients/web_application.py in prepare_request_uri(self, uri, redirect_uri, scope, state, code_challenge, code_challenge_method, **kwargs)
#      98         """
#      99         scope = self.scope if scope is None else scope
# --> 100         return prepare_grant_uri(uri, self.client_id, 'code',
#     101                                  redirect_uri=redirect_uri, scope=scope, state=state, code_challenge=code_challenge,
#     102                                  code_challenge_method=code_challenge_method, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/oauthlib/oauth2/rfc6749/parameters.py in prepare_grant_uri(uri, client_id, response_type, redirect_uri, scope, state, code_challenge, code_challenge_method, **kwargs)
#      69     """
#      70     if not is_secure_transport(uri):
# ---> 71         raise InsecureTransportError()
#      72
#      73     params = [(('response_type', response_type)),
#
# InsecureTransportError: (insecure_transport) OAuth 2 MUST utilize https.
