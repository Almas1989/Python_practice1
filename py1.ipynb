# %%
name = "Пользователь"
print("Добрый день,", name, ".")
# Out:
# Добрый день, Пользователь .

# %%
print("Добрый день, ", name, ".", sep="")
# Out:
# Добрый день, Пользователь.

# %%
name = "user"
print(f"Good day, {name}.")
# Out:
# Good day, user.

# %%
print("Привет, {}!".format(name))
print("Привет, {name}!".format(name=name))
# Out:
# Привет, user!
# Привет, user!

# %%
print("Привет, %s!" % name)
# Out:
# Привет, user!

# %%
print("\\")
# Out:
# \

# %%
print("Привет, Пользователь!")
print("Как дела?")
# Out:
# Привет, Пользователь!
# Как дела?

# %%
print("Сложно" + "подчинённый") # Сложноподчинённый
# Out:
# Сложноподчинённый

# %%
print("-" * 10)
# Out:
# ----------

# %%
print("алмас" * 10)
# Out:
# алмасалмасалмасалмасалмасалмасалмасалмасалмасалмас

# %%
a = 2 # целое число
b = 2.0 # вещественное число

# %%
n = 10 # целое число
pi = 3.14 # вещественное число

# %%
n_1 = "1"
n_2 = "2"
print(n_1 + n_2)
n_1 = int(n_1)
n_2 = int(n_2)
print(n_1 + n_2)
# Out:
# 12
# 3

# %%
x = 3.89
x = int(x)
print(x)
# Out:
# 3

# %%
width = "3.7"
height = "2.5"
s = float(width) * float(height)
print(s)
# Out:
# 9.25

# %%
int_number = int(input())
float_number = float(input())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3737/2187740766.py in <cell line: 0>()
# ----> 1 int_number = int(input())
#       2 float_number = float(input())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
n = 25
x = 0.5

print(n + x)
print(n - x)
print(n * x)
print(n / x)
print(n ** x)
# Out:
# 25.5
# 24.5
# 12.5
# 50.0
# 5.0

# %%
print(4 / 2)
# Out:
# 2.0

# %%
print(f"{2 ** 0.5:.2f}")
print(f"{2 ** 2:.3f}")
print(f"{3 ** 3:.2f}")
# Out:
# 1.41
# 4.000
# 27.00

# %%
last_digit = 1234 % 10
digit = 1234//10
print(last_digit)
print(f"{digit:.3f}")
print(f"{last_digit:.3f}")
# Out:
# 4
# 123.000
# 4.000

# %%
penultimate_digit = 1234 // 10 % 10
digit = 1234//10
digit2 = digit / 10
digit3 = digit % 10
print(digit)
print(digit2)
print(f"{digit3:.3f}")
print(penultimate_digit)
# Out:
# 123
# 12.3
# 3.000
# 3

# %%
binary_value = "1001"
print(int(binary_value, 2))
print(int(binary_value, 8))
print(int(binary_value, 16))
print(int(binary_value, 10))
# Out:
# 9
# 513
# 4097
# 1001
